# %% [markdown]
# # Esboço: robô para envio de mensagens para Telegram

# %%
import requests

def send_telegram_message(token, chat_id, message):
    url = f"https://api.telegram.org/bot7924448298:AAGt9e8TvCw7W6OjWWAvx1SLBWdbeWs1kSg/sendMessage"
    payload = {
        "chat_id": 1589047727,
        "text": message
    }
    response = requests.post(url, data=payload)
    return response.json()

# %%
# Exemplo de uso:
TOKEN = '7924448298:AAGt9e8TvCw7W6OjWWAvx1SLBWdbeWs1kSg'
CHAT_ID = 1589047727

mensagem = (
    "🗓️ 04-05-25 🕒 21:23\n\n"
    "📈 Sua ordem de COMPRA foi aberta.\n"
    "📢 Ativo: EURUSD\n"
    "📋 Bid/Ask: 1.1234 / 1.1236\n"
    "💰 Tamanho da posição: 0.01"
)
send_telegram_message(TOKEN, CHAT_ID, mensagem)
# Out:
# {'ok': True,
#  'result': {'message_id': 13,
#   'from': {'id': 7924448298,
#    'is_bot': True,
#    'first_name': 'Rainha_de_Sabá',
#    'username': 'Rainha_Saba_bot'},
#   'chat': {'id': 1589047727,
#    'first_name': 'Ciropediac',
#    'username': 'Ciropediac',
#    'type': 'private'},
#   'date': 1748822465,
#   'text': '🗓️ 04-05-25 🕒 21:23\n\n📈 Sua ordem de COMPRA foi aberta.\n📢 Ativo: EURUSD\n📋 Bid/Ask: 1.1234 / 1.1236\n💰 Tamanho da posição: 0.01'}}
