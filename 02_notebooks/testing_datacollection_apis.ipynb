# %% [markdown]
# # Data collecting

# %% [markdown]
# ## Working on csv downloaded data

# %%
import pandas as pd

df = pd.read_csv('C:/Users/progr/OneDrive/Documentos/Miguel/PROJETOS/Rainha_de_Saba/01_data/raw/EUR_USD_Historical_Data.csv')  
df
# Out:
#            Date   Price    Open    High     Low  Vol. Change %
# 0    04/16/2025  1.1399  1.1294  1.1413  1.1293   NaN    0.93%
# 1    04/15/2025  1.1294  1.1349  1.1379  1.1264   NaN   -0.48%
# 2    04/14/2025  1.1349  1.1313  1.1425  1.1282   NaN   -0.10%
# 3    04/11/2025  1.1360  1.1202  1.1475  1.1189   NaN    1.46%
# 4    04/10/2025  1.1197  1.0951  1.1242  1.0943   NaN    2.25%
# ..          ...     ...     ...     ...     ...   ...      ...
# 257  04/22/2024  1.0654  1.0656  1.0671  1.0623   NaN    0.00%
# 258  04/19/2024  1.0654  1.0645  1.0678  1.0610   NaN    0.10%
# 259  04/18/2024  1.0643  1.0672  1.0690  1.0641   NaN   -0.26%
# 260  04/17/2024  1.0671  1.0619  1.0680  1.0605   NaN    0.51%
# 261  04/16/2024  1.0617  1.0624  1.0654  1.0601   NaN   -0.05%
#
# [262 rows x 7 columns]

# %%
dataframe = pd.DataFrame(df)
dataframe
# Out:
#            Date   Price    Open    High     Low  Vol. Change %
# 0    04/16/2025  1.1399  1.1294  1.1413  1.1293   NaN    0.93%
# 1    04/15/2025  1.1294  1.1349  1.1379  1.1264   NaN   -0.48%
# 2    04/14/2025  1.1349  1.1313  1.1425  1.1282   NaN   -0.10%
# 3    04/11/2025  1.1360  1.1202  1.1475  1.1189   NaN    1.46%
# 4    04/10/2025  1.1197  1.0951  1.1242  1.0943   NaN    2.25%
# ..          ...     ...     ...     ...     ...   ...      ...
# 257  04/22/2024  1.0654  1.0656  1.0671  1.0623   NaN    0.00%
# 258  04/19/2024  1.0654  1.0645  1.0678  1.0610   NaN    0.10%
# 259  04/18/2024  1.0643  1.0672  1.0690  1.0641   NaN   -0.26%
# 260  04/17/2024  1.0671  1.0619  1.0680  1.0605   NaN    0.51%
# 261  04/16/2024  1.0617  1.0624  1.0654  1.0601   NaN   -0.05%
#
# [262 rows x 7 columns]

# %% [markdown]
# # Yahoo Finance

# %% [markdown]
# Mais informações sobre o funcionamento desta API: https://yfinance-python.org/

# %%
# !pip install yfinance --upgrade
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import yfinance as yf
import datetime

# %%
tickers = yf.Tickers('MSFT AAPL GOOG')
tickers.tickers['MSFT'].info
#yf.download(['MSFT', 'AAPL', 'GOOG'], period='1mo')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 tickers = yf.Tickers('MSFT AAPL GOOG')
# ----> 2 tickers.tickers['MSFT'].info
#       3 #yf.download(['MSFT', 'AAPL', 'GOOG'], period='1mo')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yfinance\ticker.py:142, in Ticker.info(self)
#     140 @property
#     141 def info(self) -> dict:
# --> 142     return self.get_info()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yfinance\base.py:1736, in TickerBase.get_info(self, proxy)
#    1734 def get_info(self, proxy=None) -> dict:
#    1735     self._quote.proxy = proxy
# -> 1736     data = self._quote.info
#    1737     return data
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yfinance\scrapers\quote.py:572, in Quote.info(self)
#     569 @property
#     570 def info(self) -> dict:
# ...

# %%
df = yf.download("AAPL",
    start="2011-01-01",
    end="2021-12-31",
    progress=False)
# Out:
# 1 Failed download:
# ['AAPL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2011-01-01 -> 2021-12-31)')

# %% [markdown]
# # Nasdaq Data Link

# %%
# !pip3 install nasdaq-data-link
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd
import nasdaqdatalink

nasdaqdatalink.ApiConfig.api_key = "EvCpuRsGgEqfzPV4nzwn"
data = nasdaqdatalink.get('NSE/OIL')
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import pandas as pd
# ----> 2 import nasdaqdatalink
#       4 nasdaqdatalink.ApiConfig.api_key = "EvCpuRsGgEqfzPV4nzwn"
#       5 data = nasdaqdatalink.get('NSE/OIL')
#
# ModuleNotFoundError: No module named 'nasdaqdatalink'

# %% [markdown]
# # Intrinio

# %% [markdown]
# Fazer a Intrinio funcionar é um pouco mais complexo. É necessário seguir um procediment envolendo a instalação de uma biblioteca para administração de web sockets, especificamente esta: https://pypi.org/project/websocket-client/
#
# Você deve aind executar seus códigos Intrinio utilizando o SDK (Sofwtare Ddevelpment Kit) da Intirinio específico parar Python. Link: https://github.com/intrinio/intrinio-realtime-python-sdk?tab=readme-ov-file

# %%
# !pip install intriniorealtime
# !pip install websocket-client
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# MINHA CHAVE API: "OmMwMDU4MzQwZWFjZTk3MjRjNTM3ZTQ5NTgwNDIyMGRl"

intrinio.ApiClient().set_api_key("OmMwMDU4MzQwZWFjZTk3MjRjNTM3ZTQ5NTgwNDIyMGRl")
security_api = intrinio.SecurityApi()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # MINHA CHAVE API: "OmMwMDU4MzQwZWFjZTk3MjRjNTM3ZTQ5NTgwNDIyMGRl"
# ----> 3 intrinio.ApiClient().set_api_key("OmMwMDU4MzQwZWFjZTk3MjRjNTM3ZTQ5NTgwNDIyMGRl")
#       4 security_api = intrinio.SecurityApi()
#
# NameError: name 'intrinio' is not defined

# %% [markdown]
# Para executar a verificação da API Key disponibilizada pelo Intrinio, executamos o seguinte comando no prompt:
#
# ```
# docker compose build
# docker compose run client
# ```

# %%
# !docker compose build
# !docker compose run client
# Out:
# 'docker' nao é reconhecido como um comando interno
# ou externo, um programa operável ou um arquivo em lotes.
# 'docker' nao é reconhecido como um comando interno
# ou externo, um programa operável ou um arquivo em lotes.

# %%
from intriniorealtime.client import IntrinioRealtimeClient

def on_quote(quote, backlog):
    print("QUOTE: " , quote, "BACKLOG LENGTH: ", backlog)
    
options = {
    'api_key': 'YOUR_INTRINIO_API_KEY',
    'provider': 'iex',
    'on_quote': on_quote
}

client = IntrinioRealtimeClient(options)
client.join(['AAPL','GE','MSFT'])
client.connect()
client.keep_alive()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from intriniorealtime.client import IntrinioRealtimeClient
#       3 def on_quote(quote, backlog):
#       4     print("QUOTE: " , quote, "BACKLOG LENGTH: ", backlog)
#
# ModuleNotFoundError: No module named 'intriniorealtime'

# %% [markdown]
# # Alpha Vantage

# %%
# !pip install alpha_vantage
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from alpha_vantage.timeseries import TimeSeries
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from alpha_vantage.timeseries import TimeSeries
#
# ModuleNotFoundError: No module named 'alpha_vantage'

# %%
ts = TimeSeries(key='8RDP03MYLD19D1II')
# Get json object with the intraday data and another with  the call's metadata
data, meta_data = ts.get_intraday('GOOGL')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ts = TimeSeries(key='8RDP03MYLD19D1II')
#       2 # Get json object with the intraday data and another with  the call's metadata
#       3 data, meta_data = ts.get_intraday('GOOGL')
#
# NameError: name 'TimeSeries' is not defined

# %% [markdown]
# # CoinGecko

# %% [markdown]
# https://www.coingecko.com/
#
# https://docs.coingecko.com/v3.0.1/reference/introduction
#
# https://docs.coingecko.com/reference/introduction
#
# Atenção: a CoinGecko é paga e cara!

# %%
# !pip install -U pycoingecko
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
from pycoingecko import CoinGeckoAPI
from datetime import datetime
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from pycoingecko import CoinGeckoAPI
#       2 from datetime import datetime
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'pycoingecko'

# %% [markdown]
# ### Vê-se que eu não estou muito bem servido de APIs para dados financeiros... Mas eu tenho que continuar tentado...
#
# Algumas simplesmente não parecem funcionar. Outras são muito complexas que demandarão um certo tempo para ser configuradas no meu projeto. Outras, como a CoinGecko, são pagas e bem caras.
