# %% [markdown]
# # Solving ```pip``` and Python versions at systems
#
# Explicações mais detalhadas se encontram no arquivo ```Multiplos_Pythons_sistema-pip.md```. Todos os códigos abaixo provém deste arquivo.

# %%
# !where pip
# Out:
# C:\Users\progr\.pyenv\pyenv-win\shims\pip
# C:\Users\progr\.pyenv\pyenv-win\shims\pip.bat
# C:\Users\progr\AppData\Local\Microsoft\WindowsApps\pip.exe

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\progr\AppData\Local\Programs\Python\Python312\python.exe

# %% [markdown]
# Para garantir que o pacote seja instalado exatamente na versão que o Jupyter está usando, use:

# %%
import sys
# !{sys.executable} -m pip install nome-do-pacote

# %% [markdown]
# **Dica final:**
# Sempre que estiver em ambientes com várias versões do Python, prefira usar:

# %%
# !{sys.executable} -m pip install pacote

# %% [markdown]
# # Prática
#
# Abaixo há uma demonstração das funcionalidades acima em algumas bibliotecas Python comuns:
# - Statsmodel
# - Cufflinks
# - Plotly

# %%
# !where pip
# Out:
# C:\Users\progr\.pyenv\pyenv-win\shims\pip
# C:\Users\progr\.pyenv\pyenv-win\shims\pip.bat
# C:\Users\progr\AppData\Local\Microsoft\WindowsApps\pip.exe

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\progr\AppData\Local\Programs\Python\Python312\python.exe

# %% [markdown]
# ### Statsmodel

# %%
import sys
# !{sys.executable} -m pip install statsmodels
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import statsmodels.tsa.api as smt
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# Funcionou! Vamos com outro pacote.

# %% [markdown]
# ### Cufflinks

# %%
import sys
# !{sys.executable} -m pip install cufflinks
# Out:
# ...
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cufflinks as cf

# %% [markdown]
# Aqui funcionou também!

# %% [markdown]
# ### Plotly

# %%
import sys
# !{sys.executable} -m pip install plotly
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

# %% [markdown]
# Funcionou perfeitamente aqui também!
